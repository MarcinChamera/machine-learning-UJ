# %%
import sklearn.datasets as ds
import pandas as pd

# %% [markdown]
# a) ile cech, ile rekordów

# %%
breast_cancer_ds = ds.load_breast_cancer()
breast_cancer_features_df = pd.DataFrame(breast_cancer_ds.data, columns=breast_cancer_ds.feature_names)
breast_cancer_targets_df = pd.DataFrame(breast_cancer_ds.target, columns=['class'])

# %% [markdown]
# - ile cech różne sposoby

# %%
print(len(breast_cancer_features_df.columns))
print(breast_cancer_features_df.shape[1])
# Out:
# 30
# 30

# %% [markdown]
# - ile rekordów różne sposoby

# %%
print(breast_cancer_features_df.shape[0])
print(len(breast_cancer_targets_df))
# Out:
# 569
# 569

# %% [markdown]
# b) jak się nazywają cechy i jaki mają format

# %%
breast_cancer_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %% [markdown]
# c) jak się nazywa zmienna docelowa, jakie ma wartości (jeśli klasyfikacja)

# %% [markdown]
# - jak się nazywa

# %%
breast_cancer_targets_df.columns
# Out:
# Index(['class'], dtype='object')

# %% [markdown]
# - jakie ma wartości (jeśli klasyfikacja)

# %%
breast_cancer_ds.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %% [markdown]
# d) wyświetlanie numeryczne danych: z przodu, z tyłu, inne

# %% [markdown]
# - z przodu

# %%
breast_cancer_features_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %% [markdown]
# - z tyłu

# %%
breast_cancer_features_df.tail()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# ...

# %% [markdown]
# - inne

# %%
breast_cancer_features_df.loc[10:30, ]
# Out:
#     mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 10       16.020         23.24          102.70      797.8          0.08206
# 11       15.780         17.89          103.60      781.0          0.09710
# 12       19.170         24.80          132.40     1123.0          0.09740
# 13       15.850         23.95          103.70      782.7          0.08401
# 14       13.730         22.61           93.60      578.3          0.11310
# 15       14.540         27.54           96.73      658.8          0.11390
# 16       14.680         20.13           94.74      684.5          0.09867
# 17       16.130         20.68          108.10      798.8          0.11700
# 18       19.810         22.15          130.00     1260.0          0.09831
# 19       13.540         14.36           87.46      566.3          0.09779
# 20       13.080         15.71           85.63      520.0          0.10750
# 21        9.504         12.44           60.34      273.9          0.10240
# ...

# %%
breast_cancer_features_df.head(10)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
# 7        13.71         20.83           90.20      577.9          0.11890
# 8        13.00         21.82           87.50      519.8          0.12730
# 9        12.46         24.04           83.97      475.9          0.11860
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760         0.30010              0.14710         0.2419
# ...

# %%
breast_cancer_features_df.loc[:, ['worst symmetry', 'worst fractal dimension']]
# Out:
#      worst symmetry  worst fractal dimension
# 0            0.4601                  0.11890
# 1            0.2750                  0.08902
# 2            0.3613                  0.08758
# 3            0.6638                  0.17300
# 4            0.2364                  0.07678
# ..              ...                      ...
# 564          0.2060                  0.07115
# 565          0.2572                  0.06637
# 566          0.2218                  0.07820
# 567          0.4087                  0.12400
# 568          0.2871                  0.07039
#
# [569 rows x 2 columns]

# %%
breast_cancer_features_df[['worst symmetry', 'worst fractal dimension']]
# Out:
#      worst symmetry  worst fractal dimension
# 0            0.4601                  0.11890
# 1            0.2750                  0.08902
# 2            0.3613                  0.08758
# 3            0.6638                  0.17300
# 4            0.2364                  0.07678
# ..              ...                      ...
# 564          0.2060                  0.07115
# 565          0.2572                  0.06637
# 566          0.2218                  0.07820
# 567          0.4087                  0.12400
# 568          0.2871                  0.07039
#
# [569 rows x 2 columns]

# %%
breast_cancer_features_df.iloc[100]
# Out:
# mean radius                 13.610000
# mean texture                24.980000
# mean perimeter              88.050000
# mean area                  582.700000
# mean smoothness              0.094880
# mean compactness             0.085110
# mean concavity               0.086250
# mean concave points          0.044890
# mean symmetry                0.160900
# mean fractal dimension       0.058710
# radius error                 0.456500
# texture error                1.290000
# perimeter error              2.861000
# area error                  43.140000
# smoothness error             0.005872
# compactness error            0.014880
# concavity error              0.026470
# concave points error         0.009921
# symmetry error               0.014650
# fractal dimension error      0.002355
# worst radius                16.990000
# worst texture               35.270000
# worst perimeter            108.600000
# worst area                 906.500000
# worst smoothness             0.126500
# ...
